# %%
import pyspark

# %%
file_location_1 = 'dbfs:/FileStore/tables/test1.csv'

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=4282208807809676#setting/sparkui/1227-141201-5hc4xz6p/driver-1337917966576722864">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv(file_location_1)

# %%
df_pyspark
# Out:
# Out[7]: DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |      _c0|_c1|       _c2|   _c3|
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark = spark.read.option('header','true').csv(file_location_1)

# %%
type(df_pyspark)
# Out:
# Out[10]: pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.show( )
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.head(3)
# Out:
# Out[12]: [Row(Name='Krish', age='31', Experience='10', Salary='30000'),
#  Row(Name='Sudhanshu', age='30', Experience='8', Salary='25000'),
#  Row(Name='Sunny', age='29', Experience='4', Salary='20000')]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %% [markdown]
# # Tutorial 2 - PySpark Dataframes

# %% [markdown]
# ##### Pyspark Dataframe
# ##### Reading the dataset
# ##### Checking the datatypes of the column(Schema)
# ##### Selecting Columns and Indexing
# ##### Check Describe option similar to pandas
# ##### Adding Columns
# ##### Dropping Columns
# ##### Renaming Columns

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=4282208807809676#setting/sparkui/1227-141201-5hc4xz6p/driver-1337917966576722864">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
### Reading the dataset

df_pyspark = spark.read.option('header','true').csv(file_location_1, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_pyspark = spark.read.csv(file_location_1, header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
type(df_pyspark)
# Out:
# Out[21]: pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# Out[22]: ['Name', 'age', 'Experience', 'Salary']

# %%
df_pyspark.head(3)
# Out:
# Out[23]: [Row(Name='Krish', age=31, Experience=10, Salary=30000),
#  Row(Name='Sudhanshu', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.select('Name').show()
# Out:
# +---------+
# |     Name|
# +---------+
# |    Krish|
# |Sudhanshu|
# |    Sunny|
# |     Paul|
# |   Harsha|
# |  Shubham|
# +---------+

# %%
df_pyspark.select(['Name', 'Experience']).show()
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |    Krish|        10|
# |Sudhanshu|         8|
# |    Sunny|         4|
# |     Paul|         3|
# |   Harsha|         1|
# |  Shubham|         2|
# +---------+----------+

# %%
df_pyspark['Name']
# Out:
# Out[27]: Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# Out[28]: [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_pyspark.describe()
# Out:
# Out[29]: DataFrame[summary: string, Name: string, age: string, Experience: string, Salary: string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+------+------------------+-----------------+------------------+
# |summary|  Name|               age|       Experience|            Salary|
# +-------+------+------------------+-----------------+------------------+
# |  count|     6|                 6|                6|                 6|
# |   mean|  null|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev|  null| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|Harsha|                21|                1|             15000|
# |    max| Sunny|                31|               10|             30000|
# +-------+------+------------------+-----------------+------------------+

# %%
### Adding Columns

df_pyspark = df_pyspark.withColumn('Experience after two years', df_pyspark['Experience'] + 2)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+--------------------------+
# |     Name|age|Experience|Salary|Experience after two years|
# +---------+---+----------+------+--------------------------+
# |    Krish| 31|        10| 30000|                        12|
# |Sudhanshu| 30|         8| 25000|                        10|
# |    Sunny| 29|         4| 20000|                         6|
# |     Paul| 24|         3| 20000|                         5|
# |   Harsha| 21|         1| 15000|                         3|
# |  Shubham| 23|         2| 18000|                         4|
# +---------+---+----------+------+--------------------------+

# %%
df_pyspark = df_pyspark.drop('Experience after two years')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
### Rename the columns

df_pyspark.withColumnRenamed('Name','Nick Name').show()
# Out:
# +---------+---+----------+------+
# |Nick Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# # Tutorial 3 PySpark Dataframe - Handling Missing Values

# %% [markdown]
# ##### Dropping Columns
# ##### Dropping Rows
# ##### Various Parameter in Dropping Functionalities
# ##### Handling Missing values by Mean

# %%
file_location_2 = 'dbfs:/FileStore/tables/test2.csv'

# %%
df_pyspark = spark.read.csv(file_location_2, header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# |     null|  36|      null|  null|
# +---------+----+----------+------+

# %%
df_pyspark.drop('Name').show()
# Out:
# +----+----------+------+
# | age|Experience|Salary|
# +----+----------+------+
# |  31|        10| 30000|
# |  30|         8| 25000|
# |  29|         4| 20000|
# |  24|         3| 20000|
# |  21|         1| 15000|
# |  23|         2| 18000|
# |null|      null| 40000|
# |  34|        10| 38000|
# |  36|      null|  null|
# +----+----------+------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# |     null|  36|      null|  null|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop().show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
### how, threshold, subset

df_pyspark.na.drop(how = 'any').show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.na.drop(how = 'all').show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# |     null|  36|      null|  null|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how = 'any', thresh=2).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how = 'any', subset=['Name']).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# +---------+----+----------+------+

# %%
### Fill the Missing Value

df_pyspark.na.fill('Missing Values').show()
# Out:
# +--------------+----+----------+------+
# |          Name| age|Experience|Salary|
# +--------------+----+----------+------+
# |         Krish|  31|        10| 30000|
# |     Sudhanshu|  30|         8| 25000|
# |         Sunny|  29|         4| 20000|
# |          Paul|  24|         3| 20000|
# |        Harsha|  21|         1| 15000|
# |       Shubham|  23|         2| 18000|
# |        Mahesh|null|      null| 40000|
# |Missing Values|  34|        10| 38000|
# |Missing Values|  36|      null|  null|
# +--------------+----+----------+------+

# %%
df_pyspark.na.fill('Missing Values', 'Name').show()
# Out:
# +--------------+----+----------+------+
# |          Name| age|Experience|Salary|
# +--------------+----+----------+------+
# |         Krish|  31|        10| 30000|
# |     Sudhanshu|  30|         8| 25000|
# |         Sunny|  29|         4| 20000|
# |          Paul|  24|         3| 20000|
# |        Harsha|  21|         1| 15000|
# |       Shubham|  23|         2| 18000|
# |        Mahesh|null|      null| 40000|
# |Missing Values|  34|        10| 38000|
# |Missing Values|  36|      null|  null|
# +--------------+----+----------+------+

# %%
### Not working as expected
### age column is not showing the string missing values
### bcoz of datatype conflict (my opinion)
df_pyspark.na.fill('Missing Values', ['Name','age']).show()
# Out:
# +--------------+----+----------+------+
# |          Name| age|Experience|Salary|
# +--------------+----+----------+------+
# |         Krish|  31|        10| 30000|
# |     Sudhanshu|  30|         8| 25000|
# |         Sunny|  29|         4| 20000|
# |          Paul|  24|         3| 20000|
# |        Harsha|  21|         1| 15000|
# |       Shubham|  23|         2| 18000|
# |        Mahesh|null|      null| 40000|
# |Missing Values|  34|        10| 38000|
# |Missing Values|  36|      null|  null|
# +--------------+----+----------+------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# |     null|  36|      null|  null|
# +---------+----+----------+------+

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(
                inputCols = ['age', 'Experience', 'Salary'],
                outputCols = ["{}_imputed".format(c) for c in ['age', 'Experience', 'Salary']]
                ).setStrategy("mean")

# %%
### Add Imputation cols to df
imputer.fit(df_pyspark).transform(df_pyspark).show()
# Out:
# +---------+----+----------+------+-----------+------------------+--------------+
# |     Name| age|Experience|Salary|age_imputed|Experience_imputed|Salary_imputed|
# +---------+----+----------+------+-----------+------------------+--------------+
# |    Krish|  31|        10| 30000|         31|                10|         30000|
# |Sudhanshu|  30|         8| 25000|         30|                 8|         25000|
# |    Sunny|  29|         4| 20000|         29|                 4|         20000|
# |     Paul|  24|         3| 20000|         24|                 3|         20000|
# |   Harsha|  21|         1| 15000|         21|                 1|         15000|
# |  Shubham|  23|         2| 18000|         23|                 2|         18000|
# |   Mahesh|null|      null| 40000|         28|                 5|         40000|
# |     null|  34|        10| 38000|         34|                10|         38000|
# |     null|  36|      null|  null|         36|                 5|         25750|
# ...

# %% [markdown]
# # Tutorial 4 - PySpark Dataframe Filter Operation

# %% [markdown]
# ##### Filter Operation
# ##### &  |  ==
# ##### ~

# %%
df_pyspark = spark.read.csv(file_location_1, header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
### Filter Operation

df_pyspark.filter('Salary <= 20000').show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
df_pyspark.filter('Salary <= 20000').select(['Name', 'age']).show()
# Out:
# +-------+---+
# |   Name|age|
# +-------+---+
# |  Sunny| 29|
# |   Paul| 24|
# | Harsha| 21|
# |Shubham| 23|
# +-------+---+

# %%
df_pyspark.filter(df_pyspark['Salary'] <= 20000).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
df_pyspark.filter((df_pyspark['Salary'] <= 20000) &
                  (df_pyspark['Salary']>=15000)).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
df_pyspark.filter((df_pyspark['Salary'] <= 20000) |
                  (df_pyspark['Salary']>=15000)).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.filter(~(df_pyspark['Salary'] <= 20000)).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# +---------+---+----------+------+

# %% [markdown]
# # Tutorial 5 - PySpark GroupBy and Aggregate Functions

# %%
file_location_3 = 'dbfs:/FileStore/tables/test3.csv'

# %%
df_pyspark = spark.read.csv(file_location_3, header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- salary: integer (nullable = true)

# %%
### Groupby

df_pyspark.groupBy('Name').sum()
# Out:
# Out[64]: DataFrame[Name: string, sum(salary): bigint]

# %%
df_pyspark.groupBy('Name').sum().show()
# Out:
# +---------+-----------+
# |     Name|sum(salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %%
df_pyspark.groupBy('Departments').sum().show()
# Out:
# +------------+-----------+
# | Departments|sum(salary)|
# +------------+-----------+
# |         IOT|      15000|
# |    Big Data|      15000|
# |Data Science|      43000|
# +------------+-----------+

# %%
df_pyspark.groupBy('Departments').mean().show()
# Out:
# +------------+-----------+
# | Departments|avg(salary)|
# +------------+-----------+
# |         IOT|     7500.0|
# |    Big Data|     3750.0|
# |Data Science|    10750.0|
# +------------+-----------+

# %%
df_pyspark.groupBy('Departments').count().show()
# Out:
# +------------+-----+
# | Departments|count|
# +------------+-----+
# |         IOT|    2|
# |    Big Data|    4|
# |Data Science|    4|
# +------------+-----+

# %%
df_pyspark.agg({'Salary' : 'sum'}).show()
# Out:
# +-----------+
# |sum(Salary)|
# +-----------+
# |      73000|
# +-----------+

# %%
df_pyspark.agg({'Salary' : 'avg'}).show()
# Out:
# +-----------+
# |avg(Salary)|
# +-----------+
# |     7300.0|
# +-----------+

# %% [markdown]
# # Tutorial 6 - Examples of PySpark ML

# %%
training = spark.read.csv(file_location_1, header=True, inferSchema=True)

# %%
training.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
training.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
training.columns
# Out:
# Out[74]: ['Name', 'age', 'Experience', 'Salary']

# %% [markdown]
# ##### [Age, Experience] -----> new feature -----> independent feature

# %%
from pyspark.ml.feature import VectorAssembler
feature_assembler = VectorAssembler(inputCols=["age", "Experience"], outputCol="Independent Features")

# %%
output = feature_assembler.transform(training)

# %%
output.show()
# Out:
# +---------+---+----------+------+--------------------+
# |     Name|age|Experience|Salary|Independent Features|
# +---------+---+----------+------+--------------------+
# |    Krish| 31|        10| 30000|         [31.0,10.0]|
# |Sudhanshu| 30|         8| 25000|          [30.0,8.0]|
# |    Sunny| 29|         4| 20000|          [29.0,4.0]|
# |     Paul| 24|         3| 20000|          [24.0,3.0]|
# |   Harsha| 21|         1| 15000|          [21.0,1.0]|
# |  Shubham| 23|         2| 18000|          [23.0,2.0]|
# +---------+---+----------+------+--------------------+

# %%
output.columns
# Out:
# Out[78]: ['Name', 'age', 'Experience', 'Salary', 'Independent Features']

# %%
finalized_data = output.select("Independent Features", "Salary")

# %%
finalized_data.show()
# Out:
# +--------------------+------+
# |Independent Features|Salary|
# +--------------------+------+
# |         [31.0,10.0]| 30000|
# |          [30.0,8.0]| 25000|
# |          [29.0,4.0]| 20000|
# |          [24.0,3.0]| 20000|
# |          [21.0,1.0]| 15000|
# |          [23.0,2.0]| 18000|
# +--------------------+------+

# %%
from pyspark.ml.regression import LinearRegression
train_data, test_data = finalized_data.randomSplit([0.75, 0.25])
regressor = LinearRegression(featuresCol='Independent Features', labelCol='Salary')
regressor = regressor.fit(train_data)

# %%
regressor.coefficients
# Out:
# Out[82]: DenseVector([-90.5483, 1608.7819])

# %%
regressor.intercept
# Out:
# Out[83]: 16079.13669064716

# %%
### Prediction
pred_results = regressor.evaluate(test_data)

# %%
pred_results.predictions.show()
# Out:
# +--------------------+------+-----------------+
# |Independent Features|Salary|       prediction|
# +--------------------+------+-----------------+
# |          [23.0,2.0]| 18000|17214.09079632845|
# +--------------------+------+-----------------+

# %%
pred_results.meanAbsoluteError, pred_results.meanSquaredError
# Out:
# Out[86]: (785.9092036715483, 617653.2764156472)

# %% [markdown]
# # Tutorial 7

# %%
file_location_tips = 'dbfs:/FileStore/tables/tips.csv'

# %%
df = spark.read.csv(file_location_tips, header=True, inferSchema=True)

# %%
df.show()
# Out:
# +----------+----+------+------+---+------+----+
# |total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|
# |     18.43| 3.0|  Male|    No|Sun|Dinner|   4|
# |     14.83|3.02|Female|    No|Sun|Dinner|   2|
# |     21.58|3.92|  Male|    No|Sun|Dinner|   2|
# |     10.33|1.67|Female|    No|Sun|Dinner|   3|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- total_bill: double (nullable = true)
#  |-- tip: double (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- size: integer (nullable = true)

# %%
df.columns
# Out:
# Out[91]: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
### Handling Categorical features

from pyspark.ml.feature import StringIndexer

# %%
df.show()
# Out:
# +----------+----+------+------+---+------+----+
# |total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|
# |     18.43| 3.0|  Male|    No|Sun|Dinner|   4|
# |     14.83|3.02|Female|    No|Sun|Dinner|   2|
# |     21.58|3.92|  Male|    No|Sun|Dinner|   2|
# |     10.33|1.67|Female|    No|Sun|Dinner|   3|
# ...

# %%
indexer = StringIndexer(inputCol="sex", outputCol="sex_indexed")
df_r = indexer.fit(df).transform(df)
df_r.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|
# +----------+----+------+------+---+------+----+-----------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|
# |      8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|
# |     26.88|3.12|  Male|    No|Sun|Dinner|   4|        0.0|
# |     15.04|1.96|  Male|    No|Sun|Dinner|   2|        0.0|
# |     14.78|3.23|  Male|    No|Sun|Dinner|   2|        0.0|
# |     10.27|1.71|  Male|    No|Sun|Dinner|   2|        0.0|
# |     35.26| 5.0|Female|    No|Sun|Dinner|   4|        1.0|
# |     15.42|1.57|  Male|    No|Sun|Dinner|   2|        0.0|
# ...

# %%
indexer = StringIndexer(inputCols=["smoker", "day", "time"], outputCols=["smoker_indexed", "day_indexed", "time_indexed"])
df_r = indexer.fit(df_r).transform(df_r)
df_r.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|           0.0|        1.0|         0.0|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|           0.0|        1.0|         0.0|
# |     25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|           0.0|        1.0|         0.0|
# ...

# %%
df_r.columns
# Out:
# Out[96]: ['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'sex_indexed',
#  'smoker_indexed',
#  'day_indexed',
#  'time_indexed']

# %%
featureassembler = VectorAssembler(inputCols=['tip','size','sex_indexed','smoker_indexed','day_indexed','time_indexed'],
                outputCol='Independent Features')
output = featureassembler.transform(df_r)

# %%
output.select('Independent Features').show()
# Out:
# +--------------------+
# |Independent Features|
# +--------------------+
# |[1.01,2.0,1.0,0.0...|
# |[1.66,3.0,0.0,0.0...|
# |[3.5,3.0,0.0,0.0,...|
# |[3.31,2.0,0.0,0.0...|
# |[3.61,4.0,1.0,0.0...|
# |[4.71,4.0,0.0,0.0...|
# |[2.0,2.0,0.0,0.0,...|
# |[3.12,4.0,0.0,0.0...|
# |[1.96,2.0,0.0,0.0...|
# |[3.23,2.0,0.0,0.0...|
# |[1.71,2.0,0.0,0.0...|
# |[5.0,4.0,1.0,0.0,...|
# |[1.57,2.0,0.0,0.0...|
# |[3.0,4.0,0.0,0.0,...|
# |[3.02,2.0,1.0,0.0...|
# |[3.92,2.0,0.0,0.0...|
# |[1.67,3.0,1.0,0.0...|
# |[3.71,3.0,0.0,0.0...|
# |[3.5,3.0,1.0,0.0,...|
# |(6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows

# %%
output.show()
# Out:
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|Independent Features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# |     16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|[1.01,2.0,1.0,0.0...|
# |     10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[1.66,3.0,0.0,0.0...|
# |     21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[3.5,3.0,0.0,0.0,...|
# |     23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|           0.0|        1.0|         0.0|[3.31,2.0,0.0,0.0...|
# |     24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|           0.0|        1.0|         0.0|[3.61,4.0,1.0,0.0...|
# ...

# %%
finalized_data = output.select("Independent Features","total_bill")

# %%
finalized_data.show()
# Out:
# +--------------------+----------+
# |Independent Features|total_bill|
# +--------------------+----------+
# |[1.01,2.0,1.0,0.0...|     16.99|
# |[1.66,3.0,0.0,0.0...|     10.34|
# |[3.5,3.0,0.0,0.0,...|     21.01|
# |[3.31,2.0,0.0,0.0...|     23.68|
# |[3.61,4.0,1.0,0.0...|     24.59|
# |[4.71,4.0,0.0,0.0...|     25.29|
# |[2.0,2.0,0.0,0.0,...|      8.77|
# |[3.12,4.0,0.0,0.0...|     26.88|
# |[1.96,2.0,0.0,0.0...|     15.04|
# |[3.23,2.0,0.0,0.0...|     14.78|
# |[1.71,2.0,0.0,0.0...|     10.27|
# |[5.0,4.0,1.0,0.0,...|     35.26|
# |[1.57,2.0,0.0,0.0...|     15.42|
# |[3.0,4.0,0.0,0.0,...|     18.43|
# |[3.02,2.0,1.0,0.0...|     14.83|
# |[3.92,2.0,0.0,0.0...|     21.58|
# |[1.67,3.0,1.0,0.0...|     10.33|
# |[3.71,3.0,0.0,0.0...|     16.29|
# |[3.5,3.0,1.0,0.0,...|     16.97|
# |(6,[0,1],[3.35,3.0])|     20.65|
# +--------------------+----------+
# only showing top 20 rows

# %%
train_data, test_data = finalized_data.randomSplit([0.75, 0.25])
regressor = LinearRegression(featuresCol='Independent Features', labelCol='total_bill')
regressor = regressor.fit(train_data)

# %%
regressor.coefficients
# Out:
# Out[103]: DenseVector([2.7402, 3.524, -1.6001, 2.126, 0.5657, -1.861])

# %%
regressor.intercept
# Out:
# Out[104]: 2.1221082136475804

# %%
pred_results = regressor.evaluate(test_data)

# %%
pred_results.predictions.show()
# Out:
# +--------------------+----------+------------------+
# |Independent Features|total_bill|        prediction|
# +--------------------+----------+------------------+
# |(6,[0,1],[1.25,2.0])|     10.07| 12.59539117620192|
# |(6,[0,1],[1.97,2.0])|     12.02| 14.56830836359654|
# | (6,[0,1],[2.0,2.0])|     12.69|14.650513246404648|
# | (6,[0,1],[3.0,4.0])|     20.45|24.438755518891412|
# |(6,[0,1],[3.15,3.0])|     20.08| 21.32574017682373|
# | (6,[0,1],[9.0,4.0])|     48.33|40.879732080513236|
# |[1.0,2.0,1.0,1.0,...|      5.75| 14.13336936653666|
# |[1.32,2.0,0.0,0.0...|      9.68|13.352880012093758|
# |[1.36,3.0,1.0,0.0...|     18.64|14.091187851693388|
# |[1.5,2.0,0.0,1.0,...|     15.69|15.972155837015318|
# |[1.5,2.0,0.0,1.0,...|     12.03| 17.10351072236115|
# |[1.5,2.0,1.0,0.0,...|      8.35|10.950770882022999|
# |[1.5,2.0,1.0,0.0,...|     10.65|10.950770882022999|
# |[1.5,2.0,1.0,0.0,...|     11.17|10.950770882022999|
# |[1.63,2.0,1.0,0.0...|     11.87| 11.30699204085814|
# ...

# %%
pred_results.r2 , pred_results.meanAbsoluteError, pred_results.meanSquaredError
# Out:
# Out[107]: (0.657950963619476, 3.976492185354641, 31.0257644611055)
